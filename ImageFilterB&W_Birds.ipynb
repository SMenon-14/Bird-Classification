# %% [markdown]
# <a href="https://colab.research.google.com/github/SMenon-14/Bird-Classification/blob/main/ImageFilterB%26W_Birds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/gdrive',force_remount=True)
print ('hello')
# Out:
# Mounted at /content/gdrive
# hello

# %%
from PIL import Image, ImageFilter, ImageEnhance
import os, sys
imgCount = 1;
animals = ["Flamingo", "Hummingbird", "Peacock"]
for item in animals:
  imgCount = 21;
  os.chdir('/content/gdrive/My Drive/2021TensorflowProjects/BirdClassification/Birds/Training/'+item)
  for root, dirs, files in os.walk("."):
    for filename in files:
      print (filename)
      im = Image.open(filename)
      f, e = os.path.splitext(filename)
      enhanced_im = im.convert('L') #convert image to monochrome
      enhanced_im = im.convert('1') #convert image to black and white
      enhanced_im.save('Grayscale' + str(imgCount) + ' - ' + item +'.jpg', 'JPEG', quality=90)
      print('SavedImages')
      imgCount=imgCount+1
# Out:
# A1 - Flamingo.jpg
# SavedImages
# A2 - Flamingo.jpg
# SavedImages
# A3 - Flamingo.jpg
# SavedImages
# A4 - Flamingo.jpg
# SavedImages
# A5 - Flamingo.jpg
# SavedImages
# A6 - Flamingo.jpg
# SavedImages
# A7 - Flamingo.jpg
# SavedImages
# A8 - Flamingo.jpg
# SavedImages
# A9 - Flamingo.jpg
# SavedImages
# A10 - Flamingo.jpg
# SavedImages
# A11 - Flamingo.jpg
# SavedImages
# A12 - Flamingo.jpg
# SavedImages
# A13 - Flamingo.jpg
# SavedImages
# A14 - Flamingo.jpg
# SavedImages
# A15 - Flamingo.jpg
# SavedImages
# A16 - Flamingo.jpg
# SavedImages
# A17 - Flamingo.jpg
# SavedImages
# A18 - Flamingo.jpg
# SavedImages
# A19 - Flamingo.jpg
# SavedImages
# A20 - Flamingo.jpg
# SavedImages
# A21 - Flamingo.jpg
# SavedImages
# A22 - Flamingo.jpg
# SavedImages
# A23 - Flamingo.jpg
# SavedImages
# A24 - Flamingo.jpg
# SavedImages
# A25 - Flamingo.jpg
# SavedImages
# A26 - Flamingo.jpg
# SavedImages
# A27 - Flamingo.jpg
# SavedImages
# A28 - Flamingo.jpg
# SavedImages
# A29 - Flamingo.jpg
# ...
